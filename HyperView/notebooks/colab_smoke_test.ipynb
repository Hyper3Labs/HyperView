# %% [markdown]
# # HyperView — Colab Smoke Test
#
# This notebook verifies that HyperView can launch inside Google Colab and open the UI in a new browser tab.
#
# The smoke test uses a synthetic dataset (random images + precomputed 2D coordinates), so it does not download models or run embedding computation.

# %%
# %%pip install -q git+https://github.com/Hyper3Labs/HyperView.git
# Out:
# zsh:1: command not found: pip
# Cloning into 'HyperView'...
# remote: Enumerating objects: 577, done.
# remote: Counting objects: 100% (577/577), done.
# remote: Compressing objects: 100% (328/328), done.
# remote: Total 577 (delta 240), reused 518 (delta 193), pack-reused 0 (from 0)
# Receiving objects: 100% (577/577), 4.29 MiB | 8.76 MiB/s, done.
# Resolving deltas: 100% (240/240), done.
# /Users/matin/hyperview_org/HyperView/notebooks/HyperView
# Using Python 3.12.8 environment at: /Users/matin/hyperview_org/HyperView/.venv
# error: /Users/matin/hyperview_org/HyperView/notebooks/HyperView does not appear to be a Python project, as neither `pyproject.toml` nor `setup.py` are present in the directory

# %%
import numpy as np

import hyperview as hv
from hyperview.core.sample import SampleFromArray

dataset = hv.Dataset("colab_smoke", persist=False)

rng = np.random.default_rng(0)
num_samples = 200

for i in range(num_samples):
    img = (rng.random((64, 64, 3)) * 255).astype(np.uint8)

    sample = SampleFromArray.from_array(
        id=f"s{i}",
        image_array=img,
        label=f"class_{i % 10}",
        metadata={"i": i},
    )

    # Precomputed 2D Euclidean projection
    sample.embedding_2d = [float(rng.normal()), float(rng.normal())]

    # Precomputed 2D hyperbolic projection (inside unit disk)
    r = float(rng.random() * 0.95)
    theta = float(rng.random() * 2 * np.pi)
    sample.embedding_2d_hyperbolic = [float(r * np.cos(theta)), float(r * np.sin(theta))]

    dataset.add_sample(sample)

hv.launch(dataset, port=6262)

# %% [markdown]
# Click the link printed above to open HyperView in a new tab. If needed, copy/paste the URL.
